# %%
import jax.numpy as jnp

# %%
A = jnp.array([1, 2, 3])
mask = jnp.array([True,True,False])
mask_indices = jnp.where(mask)[0]

# %%
jnp.sum(A[mask])
# Out:
# Array(3, dtype=int32)

# %%
A = A.at[mask].add( - 1 )
A
# Out:
# Array([0, 1, 3], dtype=int32)

# %%
A = jnp.array([[1, 2, 3,4], 
               [4, 5, 6,5], 
               [7, 8, 9,2]]
               )
jnp.linalg.norm(A, axis=1)
# Out:
# Array([ 5.477226, 10.099504, 14.071247], dtype=float32)
